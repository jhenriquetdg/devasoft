# %%
from googletrans import Translator
import os
import re
from shutil import copyfile
import sys

# Babel -> Google dictionary

translation_dir = "/home/zetdg/Devasoft/devasoft"
translation_dir = ''

translator      = Translator()
translation_dir = translation_dir+"./app/translations"

lang_dir = sys.argv;
lang_dir = os.listdir(translation_dir)
print(lang_dir)

if len(lang_dir) == 1:
    lang_dir = os.listdir(translation_dir)
else:
    lang_dir = lang_dir[1:]

    lang_dir = os.listdir(translation_dir)

for f,lang_acronyms in enumerate(lang_dir):
    print(f,lang_acronyms)
    message_file = os.path.join(translation_dir,lang_acronyms,'LC_MESSAGES/messages.po')


    print(str(f) + ' of ' + str(len(lang_dir)),lang_acronyms,message_file)
    
    if not os.path.isfile(message_file):
        print("\tFile {} doesn't exist".format(message_file))
        continue

    mfile    = open(message_file,"r")
    
    
    id_source        = []
    id_translate     = []
    translated_lines = []
    
    all_lines = mfile.readlines();
    mfile.close()
    translated_lines = all_lines
    
    for l,line in enumerate(all_lines):
        split_line = line.split(" ")
        
        if split_line[0]=='msgid':
            id_source.append(l)
            
        if split_line[0]=='msgstr':
            id_translate.append(l)
    
    
    cont = 0;
    for s,t in zip(id_source,id_translate):
        cont = cont + 1;
        
        source_text = re.findall('(\".+?\")',all_lines[s])
        translate_text = re.findall('(\".+?\")',all_lines[t])
        
        if not len(translate_text)==0:
            continue
        
        if len(source_text):
            print(str(cont) + ' of ' + str(len(id_translate)))
            source_text = source_text[0]
            source_text = source_text[1:-1]
            
            
            Splitted    = re.split("(\%\(.+?\)s)",source_text)
            #TagName     = re.findall("(\%\(.+?\)s)",source_text)
            Dummy       = re.sub("(\%\(.+?\)s)","_@ZWWZ@_",source_text)

            Translated          = translator.translate(Dummy, dest=lang_acronyms)
            Translated          = Translated.text

            SplittedTranslation = re.split("(_\s*@.+?ZWWZ.+?@\s*_)",Translated)

            translated_text = []
            for c,chunk in enumerate(Splitted):
                if c % 2:
                    translated_text.append(Splitted[c])
                else:
                    translated_text.append(SplittedTranslation[c])

            translated_text     = ''.join(translated_text)
            translated_lines[t] = 'msgstr "'+ translated_text +'"\n'

            #print(source_text, '->', translated_lines[t], end='')
            print('\t'+source_text, '->', translated_text)
# Out:
# ['pt', 'es']
# 0 pt
# 0 of 2 pt ./app/translations/pt/LC_MESSAGES/messages.po
# 2 of 59
# 	Please log in to access this page. -> Faça o login para acessar esta página.
# 3 of 59
# 	Error: the translation service is not configured. -> Erro: o serviço de tradução não está configurado.
# 4 of 59
# 	Error: the translation service failed. -> Erro: o serviço de tradução falhou.
# 5 of 59
# 	[Microblog] Reset Your Password -> [Microblog] Repor a sua senha
# 6 of 59
# 	Username -> Nome de usuário
# 7 of 59
# 	Password -> Senha
# 8 of 59
# 	Remember Me -> Lembre de mim
# 9 of 59
# 	Sign In -> Assinar em
# 10 of 59
# 	Email -> O email
# 11 of 59
# 	Repeat Password -> Repita a senha
# 12 of 59
# 	Register -> registo
# 13 of 59
# 	Please use a different username. -> Use um nome de usuário diferente.
# 14 of 59
# 	Please use a different email address. -> Por favor, use um endereço de e-mail diferente.
# 15 of 59
# 	Request Password Reset -> Solicitar redefinição de senha
# 16 of 59
# 	Invalid username or password -> nome de usuário ou senha inválidos
# 17 of 59
# 	Congratulations, you are now a registered user! -> Parabéns, agora você é um usuário registrado!
# 18 of 59
# 	Check your email for the instructions to reset your password -> Verifique o seu email para obter as instruções para redefinir sua senha
# 19 of 59
# 	Your password has been reset. -> Sua senha foi alterada.
# 20 of 59
# 	About me -> Sobre mim
# 21 of 59
# 	Submit -> Enviar
# 22 of 59
# 	Say something -> Diga algo
# 23 of 59
# 	Your post is now live! -> Seu post está agora ao vivo!
# 24 of 59
# 	Your changes have been saved. -> Suas alterações foram salvas.
# 25 of 59
# 	Edit Profile -> Editar Perfil
# 26 of 59
# 	User %(username)s not found. -> Usuário %(username)s não encontrado.
# 27 of 59
# 	You cannot follow yourself! -> Você não pode seguir a si mesmo!
# 28 of 59
# 	You are following %(username)s! -> Você está seguindo %(username)s!
# 29 of 59
# 	You cannot unfollow yourself! -> Você não pode deixar de seguir você mesmo!
# 30 of 59
# 	You are not following %(username)s. -> Você não está seguindo %(username)s.
# 31 of 59
# 	%(username)s said %(when)s -> %(username)s disse %(when)s
# 32 of 59
# 	Translate -> Traduzir
# 33 of 59
# 	Welcome to Devasoft -> Bem-vindo ao Devasoft
# 34 of 59
# 	Home -> Casa
# 35 of 59
# 	Explore -> Explorar
# 36 of 59
# 	Login -> Login
# 37 of 59
# 	Profile -> Perfil
# 38 of 59
# 	Logout -> Sair
# 39 of 59
# 	Error: Could not contact server. -> Erro: Não foi possível entrar em contato com o servidor.
# 40 of 59
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-e751b754221f> in <module>()
#      86                     translated_text.append(Splitted[c])
#      87                 else:
# ---> 88                     translated_text.append(SplittedTranslation[c])
#      89
#      90             translated_text     = ''.join(translated_text)
#
# IndexError: list index out of range

# %%
print(Translated)
print(Dummy)
# Out:
# Hin, _ @ KENKEN @ _!
# Hi, _@TOKEN@_!
